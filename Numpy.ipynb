# %% [markdown]
# <a href="https://colab.research.google.com/github/Vinamrath/Data-Analysis-with-Python/blob/main/Numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![images.png](data:image/png;base64,...)

# %%
import sys
import numpy as np

# %% [markdown]
# Basic Numpy Arrays

# %%
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
a = np.array([1,2,3,4])

# %%
b = np.array([0,-5,1,1.5,2])

# %%
a[0],a[1]
# Out:
# (np.int64(1), np.int64(2))

# %%
a[0:]
# Out:
# array([1, 2, 3, 4])

# %%
b[1:3]
# Out:
# array([-5.,  1.])

# %%
b[0:-1]
# Out:
# array([ 0. , -5. ,  1. ,  1.5])

# %%
b[[0,2,-1]]
# Out:
# array([0., 1., 2.])

# %% [markdown]
# Result is another Numpy array. Lot faster.

# %% [markdown]
# ARRAY TYPES

# %% [markdown]
# As Numpy array is continuosly assigned in memory. The Numpy library needs to know what the type of object your storing. you cant store a string , a  num. It will not be able to provide performance and optimizations for arrays not consistent insights. Like every element should be of same type in Numpy unlike in regular python.

# %%
a

# %%
b.dtype

# %%
a.dtype

# %%
c = np.array([1,2,3,4],dtype=np.float64)

# %%
c

# %%
np.array(c).dtype

# %%
d = (['apple','b','c'])

# %%
np.array(d).dtype
# Out:
# dtype('<U5')

# %%
grid = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

# %%
np.array(grid).shape
# Out:
# (3, 3)

# %%
grid.size

# %%
grid + 100

# %%
grid.itemsize
# Out:
# 8

# %% [markdown]
# A[d1, d2, d3...] &nbsp; &nbsp; &nbsp; &nbsp; , &nbsp; &nbsp; &nbsp; &nbsp; d1, d2, d3... represent dimensions
